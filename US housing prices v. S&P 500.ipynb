# %%
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#mydata = quandl.get("FMAC/HPI", authtoken="")
s_p_500 = quandl.get("MULTPL/SP500_REAL_PRICE_MONTH", authtoken="whC5HyRXsB2xeo19iVuy")

# %% [markdown]
# ## Freddie Mac House Price Index
#
# ### measures the price changes of residential housing as a percentage change from some specific start date

# %%
mydata.head()
# Out:
#                    AK         AL         AR         AZ         CA         CO  \
# Date
# 1975-01-31  34.371830  35.695975  36.738861  28.937735  15.722312  19.603977
# 1975-02-28  34.880945  35.896770  37.098962  29.463708  15.775202  19.837138
# 1975-03-31  35.402217  36.133518  37.416398  29.959514  15.964942  20.073483
# 1975-04-30  35.944703  36.425723  37.677813  30.345148  16.275547  20.301864
# 1975-05-31  36.535272  36.695708  37.921099  30.546449  16.533017  20.495075
#
#                    CT         DC         DE         FL  ...         TX  \
# Date                                                    ...
# 1975-01-31  24.369431  18.255987  27.264842  30.997043  ...  32.602350
# 1975-02-28  24.908036  18.382701  27.250734  32.229049  ...  32.944116
# 1975-03-31  25.313556  18.514587  27.268478  34.027506  ...  33.542975
# 1975-04-30  25.541141  18.689302  27.362673  36.218077  ...  34.402826
# 1975-05-31  25.614056  18.937116  27.561893  36.437855  ...  34.649755
#
# ...

# %%
s_p_500.head()
# Out:
#             Value
# Date
# 1871-01-01   4.44
# 1871-02-01   4.50
# 1871-03-01   4.61
# 1871-04-01   4.74
# 1871-05-01   4.86

# %%
states = mydata.columns; states
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
#        'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA',
#        'WI', 'WV', 'WY', 'United States not seasonaly adjusted',
#        'United States seasonaly adjusted'],
#       dtype='object')

# %%
massachusetts = mydata['MA']; massachusetts.head()
# Out:
# Date
# 1975-01-31    15.901880
# 1975-02-28    15.800139
# 1975-03-31    15.698375
# 1975-04-30    15.618190
# 1975-05-31    15.583616
# Name: MA, dtype: float64

# %%
#plot massachusetts
plt.plot(massachusetts, color='green')
plt.ylabel('FMHPI')
plt.title('Massachusetts')
plt.show()

# %%
#plot NY
plt.plot(mydata['NY'], color='red')
plt.ylabel('FMHPI')
plt.title('New York')
plt.show()

# %%
#plot next to eachother
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(mydata['MA'], color='green')
plt.ylabel('FMHPI')
plt.title('Massachusetts')

# plt.subplot(1, 2, 2)
# plt.plot(mydata['NY'], color='red')
# plt.ylabel('FMHPI')
# plt.title('New York')

plt.subplot(1, 2, 2)
plt.plot(mydata['FL'], color='blue')
plt.ylabel('FMHPI')
plt.title('Florida')

plt.tight_layout()
plt.show()

# %%
x = mydata['MA']

plt.hist(x, bins=60, color='red')
plt.title('Massachusetts')
plt.xlabel('FMHPI')
plt.show()

# %%
#boxplot MA & FL next to eachother
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.boxplot(mydata['MA'])
plt.ylabel('FMHPI')
plt.title('Massachusetts')

plt.subplot(1, 2, 2)
plt.boxplot(mydata['FL'])
plt.ylabel('FMHPI')
plt.title('Florida')

plt.tight_layout()
plt.show()

# %%
def plot_data(city,color):
    plt.plot(mydata[city], color=color)
    plt.ylabel('FMHPI')
    plt.title(city)
    plt.show()

# %%
US_not_season = 'United States not seasonaly adjusted'
US_season = 'United States seasonaly adjusted'

plot_data(US_not_season,'red')

# %%
plot_data(US_season, 'blue')

# %%
#plot_data(s_p_500['value'], 'green')
